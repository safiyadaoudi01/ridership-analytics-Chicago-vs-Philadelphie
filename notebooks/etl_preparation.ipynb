# %% [markdown]
# ## Import et préparation des données

# %% [markdown]
# ### Fichiers csv et excel de chicago

# %%
import pandas as pd

df_chicago_route = pd.read_csv('../data/chicago_csv/CTA_Ridership_Daily_by_Route.csv')
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_18036\3259828267.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_chicago_route = pd.read_csv('../data/chicago_csv/CTA_Ridership_Daily_by_Route.csv')

# %%
df_chicago_route.head()
# Out:
#          date route day_type  ridership
# 0  2013-06-24   103        W       2325
# 1  2022-09-27   111        W       1777
# 2  2024-03-04  1001        W          9
# 3  2001-09-06   103        W       4976
# 4  2016-10-31   100        W        712

# %%
df_chicago_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092474 entries, 0 to 1092473
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   date       1092474 non-null  object
#  1   route      1092474 non-null  object
#  2   day_type   1092474 non-null  object
#  3   ridership  1092474 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 33.3+ MB

# %%
import pandas as pd

# Extraire l'année et le mois de df_chicago_daily
df_chicago_route['date'] = pd.to_datetime(df_chicago_route['date'])
df_chicago_route['year'] = df_chicago_route['date'].dt.year.astype(int)

# %%
df_chicago_route=df_chicago_route[df_chicago_route['year'] >= 2019]

# %%
df_chicago_route.shape
# Out:
# (288929, 5)

# %%
df_chicago_mode=pd.read_excel('../data/chicago_excel/cta-ridership-daily-boarding-totals.xlsx')

# %%
df_chicago_mode['service_date'] = pd.to_datetime(df_chicago_mode['service_date'])
df_chicago_mode['year'] = df_chicago_mode['service_date'].dt.year.astype(int)

df_chicago_mode=df_chicago_mode[df_chicago_mode['year'] >= 2019]

# %%
df_chicago_mode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2526 entries, 6574 to 9099
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   service_date    2526 non-null   datetime64[ns]
#  1   day_type        2526 non-null   object
#  2   bus             2526 non-null   int64
#  3   rail_boardings  2526 non-null   int64
#  4   total_rides     2526 non-null   int64
#  5   year            2526 non-null   int32
# dtypes: datetime64[ns](1), int32(1), int64(3), object(1)
# memory usage: 128.3+ KB

# %% [markdown]
# ### Fichiers csv de Philadelphie

# %%
import pandas as pd

df_phil_mode = pd.read_csv('../data/philadelphia_csv/Average_Daily_Ridership_By_Mode - City of Philadelphia.csv')
df_phil_route=pd.read_csv('../data/philadelphia_csv/Average_Daily_Ridership_By_Route - City of Philadelphia.csv')

# %%
df_phil_mode.head()
# Out:
#    Calendar_Year  Calendar_Month               Mode  Average_Daily_Ridership  \
# 0           2019               1                Bus                   459160
# 1           2019               1                CCT                     4294
# 2           2019               1         Heavy Rail                   296709
# 3           2019               1      Regional Rail                   122856
# 4           2019               1  Trackless Trolley                    16853
#
#     Source  ObjectId
# 0      APC         1
# 1  Revenue         2
# 2  Revenue         3
# 3  Revenue         4
# 4      APC         5

# %%
df_phil_mode.columns
# Out:
# Index(['Calendar_Year', 'Calendar_Month', 'Mode', 'Average_Daily_Ridership',
#        'Source', 'ObjectId'],
#       dtype='object')

# %%
df_phil_mode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Calendar_Year            492 non-null    int64
#  1   Calendar_Month           492 non-null    int64
#  2   Mode                     492 non-null    object
#  3   Average_Daily_Ridership  492 non-null    int64
#  4   Source                   492 non-null    object
#  5   ObjectId                 492 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 23.2+ KB

# %%
df_phil_route.head()
# Out:
#    Calendar_Year  Calendar_Month Route  Average_Daily_Ridership Source  \
# 0           2019               8    59                     3811    APC
# 1           2019               8    60                     8550    APC
# 2           2019               8    61                     3563    APC
# 3           2019               8    62                      226    APC
# 4           2019               8    64                     4335    APC
#
#    ObjectId
# 0         2
# 1         3
# 2         4
# 3         5
# 4         6

# %%
df_phil_route.columns
# Out:
# Index(['Calendar_Year', 'Calendar_Month', 'Route', 'Average_Daily_Ridership',
#        'Source', 'ObjectId'],
#       dtype='object')

# %%
df_phil_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10994 entries, 0 to 10993
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Calendar_Year            10994 non-null  int64
#  1   Calendar_Month           10994 non-null  int64
#  2   Route                    10994 non-null  object
#  3   Average_Daily_Ridership  10994 non-null  int64
#  4   Source                   10994 non-null  object
#  5   ObjectId                 10994 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 515.5+ KB

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Route

# %%
df_phil_route.head()
# Out:
#    Calendar_Year  Calendar_Month Route  Average_Daily_Ridership Source  \
# 0           2019               8    59                     3811    APC
# 1           2019               8    60                     8550    APC
# 2           2019               8    61                     3563    APC
# 3           2019               8    62                      226    APC
# 4           2019               8    64                     4335    APC
#
#    ObjectId
# 0         2
# 1         3
# 2         4
# 3         5
# 4         6

# %%
df_chicago_route.head()
# Out:
#         date route day_type  ridership  year
# 1 2022-09-27   111        W       1777  2022
# 2 2024-03-04  1001        W          9  2024
# 6 2020-06-03    11        W        261  2020
# 7 2022-06-29  1001        W         65  2022
# 8 2023-08-04   111        W       1868  2023

# %% [markdown]
# #### Ajouter la colonne 'month' dans 'df_chicago_route' pour faire une comparaison mensuelle

# %%
df_chicago_route["month"]=df_chicago_route["date"].dt.month

# %% [markdown]
# #### Suppression des colonnes inutile dans df_phil_route

# %%
df_phil_route=df_phil_route.drop(columns=['Source', 'ObjectId'])

# %% [markdown]
# #### Grouper par l'année,le mois et la route pour avoir la moyenne par mois de 'ridership' dans df_chicago_route

# %%
df_chicago_route_monthly = (
    df_chicago_route
    .groupby(['year', 'month', 'route'], as_index=False)
    .agg({
        'ridership': 'mean'
    })
)

# %% [markdown]
# ### Vérification des colonnes

# %%
df_chicago_route_monthly.columns
# Out:
# Index(['year', 'month', 'route', 'ridership'], dtype='object')

# %%
df_phil_route.columns
# Out:
# Index(['Calendar_Year', 'Calendar_Month', 'Route', 'Average_Daily_Ridership'], dtype='object')

# %%
df_phil_route.shape
# Out:
# (10994, 4)

# %%
df_chicago_route_monthly.shape
# Out:
# (12169, 4)

# %% [markdown]
# #### Fusionnement de df_chicago_route_monthly et df_phil_route

# %%
df_chicago_route_monthly['city']='Chicago'

# %%
df_chicago_route_clean = df_chicago_route_monthly.rename(columns={
    'ridership': 'avg_ridership'
})

# %%
df_phil_route['city']='Philadelphia'

# %%
df_phil_route_clean = df_phil_route.rename(columns={
    'Calendar_Year': 'year',
    'Calendar_Month': 'month',
    'Route': 'route',
    'Average_Daily_Ridership': 'avg_ridership'
})

# %%
df_route_comparison = pd.concat(
    [df_chicago_route_clean, df_phil_route_clean],
    ignore_index=True
)

# %%
df_route_comparison.head()
# Out:
#    year  month route  avg_ridership     city
# 0  2019      1     2    2911.714286  Chicago
# 1  2019      1     4   14058.611111  Chicago
# 2  2019      1    15    5347.052632  Chicago
# 3  2019      1    18    2807.750000  Chicago
# 4  2019      1    19     172.100000  Chicago

# %%
df_route_comparison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23163 entries, 0 to 23162
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           23163 non-null  int64
#  1   month          23163 non-null  int64
#  2   route          23163 non-null  object
#  3   avg_ridership  23163 non-null  float64
#  4   city           23163 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 904.9+ KB

# %%
df_route_comparison.to_csv('../data/processed/route_comparison.csv', index=False)

# %% [markdown]
# ### Mode

# %%
df_chicago_mode.head()
# Out:
#      service_date day_type     bus  rail_boardings  total_rides  year
# 6574   2019-01-01        U  248879          245852       494731  2019
# 6575   2019-01-02        W  591006          573542      1164548  2019
# 6576   2019-01-03        W  664442          627781      1292223  2019
# 6577   2019-01-04        W  668812          628514      1297326  2019
# 6578   2019-01-05        A  444434          348257       792691  2019

# %%
df_phil_mode.head()
# Out:
#    Calendar_Year  Calendar_Month               Mode  Average_Daily_Ridership  \
# 0           2019               1                Bus                   459160
# 1           2019               1                CCT                     4294
# 2           2019               1         Heavy Rail                   296709
# 3           2019               1      Regional Rail                   122856
# 4           2019               1  Trackless Trolley                    16853
#
#     Source  ObjectId
# 0      APC         1
# 1  Revenue         2
# 2  Revenue         3
# 3  Revenue         4
# 4      APC         5

# %% [markdown]
# #### les modes qu'on va comparer concerne juste 'bus' et 'rail'

# %%
df_phil_mode=df_phil_mode[df_phil_mode['Mode'].isin(['Bus', 'Heavy Rail', 'Regional Rail'])]

# %%
df_phil_mode['Mode'].unique()
# Out:
# array(['Bus', 'Heavy Rail', 'Regional Rail'], dtype=object)

# %% [markdown]
# #### Ajout de la colonne mois dans df_chicago_mode pour faire une comparaison mensuelle

# %%
df_chicago_mode["month"]=df_chicago_mode["service_date"].dt.month

# %%
df_chicago_mode.head()
# Out:
#      service_date day_type     bus  rail_boardings  total_rides  year  month
# 6574   2019-01-01        U  248879          245852       494731  2019      1
# 6575   2019-01-02        W  591006          573542      1164548  2019      1
# 6576   2019-01-03        W  664442          627781      1292223  2019      1
# 6577   2019-01-04        W  668812          628514      1297326  2019      1
# 6578   2019-01-05        A  444434          348257       792691  2019      1

# %% [markdown]
# #### Restructurer les colonnes de df_chicago_mode pour etre comparable avec df_phil_mode

# %% [markdown]
# ##### Étape 1 : agrégation mensuelle (moyenne journalière)

# %%
df_chicago_monthly_mode = (
    df_chicago_mode
    .groupby(['year', 'month'], as_index=False)
    .agg({
        'bus': 'mean',
        'rail_boardings': 'mean'
    })
)

# %%
df_chicago_monthly_mode.head()
# Out:
#    year  month            bus  rail_boardings
# 0  2019      1  563028.000000   518349.838710
# 1  2019      2  652809.857143   584176.464286
# 2  2019      3  653778.935484   581263.516129
# 3  2019      4  664562.666667   612854.966667
# 4  2019      5  682092.516129   619579.677419

# %% [markdown]
# ##### Étape 2 : passage en format long (mode)

# %%
df_chicago_monthly_mode = df_chicago_monthly_mode.melt(
    id_vars=['year', 'month'],
    value_vars=['bus', 'rail_boardings'],
    var_name='mode',
    value_name='ridership'
)

# %%
df_chicago_monthly_mode.head()
# Out:
#    year  month mode      ridership
# 0  2019      1  bus  563028.000000
# 1  2019      2  bus  652809.857143
# 2  2019      3  bus  653778.935484
# 3  2019      4  bus  664562.666667
# 4  2019      5  bus  682092.516129

# %% [markdown]
# #### Renommer les variables 'Heavy Rail' et 'Regional Rail' comme 'rail_boardings' dans df_phil_mode pour le comparer avec 'rail_boardings' de df_chicago_monthly_mode

# %%
df_phil_mode['Mode'] = df_phil_mode['Mode'].replace({
    'Heavy Rail': 'rail_boardings',
    'Regional Rail': 'rail_boardings'
})

# %%
df_phil_mode['Mode'] = df_phil_mode['Mode'].replace({'Bus': 'bus'})

# %%
df_phil_mode['Mode'].unique()
# Out:
# array(['bus', 'rail_boardings'], dtype=object)

# %% [markdown]
# #### Supprimer les dubliqués dans df_phil_mode aprer renommer les deux types de Rail juste par 'rail_boardings'

# %%
df_phil_mode.duplicated(subset=['Calendar_Year', 'Calendar_Month', 'Mode']).sum()
# Out:
# 82

# %%
df_phil_mode=df_phil_mode.groupby(['Calendar_Year', 'Calendar_Month','Mode'], as_index=False).agg({
        'Average_Daily_Ridership': 'sum'})

# %%
df_phil_mode.duplicated(subset=['Calendar_Year', 'Calendar_Month', 'Mode']).sum()
# Out:
# 0

# %% [markdown]
# #### Verification des colonnes

# %%
df_chicago_monthly_mode.columns
# Out:
# Index(['year', 'month', 'mode', 'ridership'], dtype='object')

# %%
df_phil_mode.columns
# Out:
# Index(['Calendar_Year', 'Calendar_Month', 'Mode', 'Average_Daily_Ridership'], dtype='object')

# %% [markdown]
# #### Fusionnement de df_chicago_monthly_mode et df_phil_mode

# %%
df_phil_mode_clean = df_phil_mode.rename(columns={
    'Calendar_Year': 'year',
    'Calendar_Month': 'month',
    'Mode': 'mode',
    'Average_Daily_Ridership': 'avg_ridership_philadelphia'
})

# %%
df_chicago_mode_clean = df_chicago_monthly_mode.rename(columns={
    'ridership': 'avg_ridership_chicago'
})

# %%
df_mode_comparison = pd.merge(
    df_chicago_mode_clean,
    df_phil_mode_clean,
    on=['year', 'month', 'mode'],
    how='inner'
)

# %%
df_mode_comparison.head()
# Out:
#    year  month mode  avg_ridership_chicago  avg_ridership_philadelphia
# 0  2019      1  bus          563028.000000                      459160
# 1  2019      2  bus          652809.857143                      464674
# 2  2019      3  bus          653778.935484                      478487
# 3  2019      4  bus          664562.666667                      473732
# 4  2019      5  bus          682092.516129                      480074

# %%
df_mode_comparison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   year                        164 non-null    int32
#  1   month                       164 non-null    int32
#  2   mode                        164 non-null    object
#  3   avg_ridership_chicago       164 non-null    float64
#  4   avg_ridership_philadelphia  164 non-null    int64
# dtypes: float64(1), int32(2), int64(1), object(1)
# memory usage: 5.3+ KB

# %%
df_mode_comparison.to_csv('../data/processed/mode_comparison.csv', index=False)
